# %%
names=[]
id=[]
age=[]
for i in range(5):
  names.append(input())
  id.append(int(input()))
  age.append(int(input()))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 6
#       4 for i in range(5):
#       5   names.append(input())
# ----> 6   id.append(int(input()))
#       7   age.append(int(input()))
#
# ValueError: invalid literal for int() with base 10: ''

# %%
names,id,age
# Out:
# (['mukter', 'emon', 'rafi', 'mejba', 'tahsin'],
#  [388, 402, 392, 401, 405],
#  [24, 24, 25, 25, 26])

# %%
dict = {'names':names,'id':id,'age':age}

# %%
dict
# Out:
# {'names': ['mukter', 'emon', 'rafi', 'mejba', 'tahsin'],
#  'id': [388, 402, 392, 401, 405],
#  'age': [24, 24, 25, 25, 26]}

# %%
import pandas as pd
df=pd.DataFrame(dict)
df
# Out:
#     names   id  age
# 0  mukter  388   24
# 1    emon  402   24
# 2    rafi  392   25
# 3   mejba  401   25
# 4  tahsin  405   26

# %%
df.describe()
# Out:
#                id       age
# count    5.000000   5.00000
# mean   397.600000  24.80000
# std      7.231874   0.83666
# min    388.000000  24.00000
# 25%    392.000000  24.00000
# 50%    401.000000  25.00000
# 75%    402.000000  25.00000
# max    405.000000  26.00000

# %%
df.to_csv('mydata.csv')
